# %% [markdown]
# # Tasks:
#
# ### 1
# - ---  Take a look at the dataset
# - ---  Write some basic codes (like preprocessing, ..)
# - ---  Number of data should be more than 10 times of features
# - Do feature selection (like Lasso, Mrmr, rfe, hierarchial, ..)
# - Read feature selection, data preprocessing, outlier, ..
# - ANY models for classification (like linear, RF, XgBoost, Adaboost, new models, ..)
# - We need Cross validation methods(leave-one-out, k-fold, nested, ..) because data is small
#
#
# ### 2
# - 4 excels, each for one image dataset
# - a problem: intravariety, diffrence between Dr segmentations
# - We have 2 Drs for masking -> 4*2=8 datasets
# - Modeling once
# - Data concatenation 2by2 and 3by3 and 4by4
